# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
# !pip install geopandas
# !pip install plotly_express

# %%
import json
import pandas as pd
import os
import glob
import re
import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import matplotlib.pyplot as plt
import plotly_express as px
import tqdm
from tqdm._tqdm_notebook import tqdm_notebook
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: TqdmDeprecationWarning:
#
# This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`

# %%
list_files = glob.glob("/content/drive/My Drive/Data science/Projets Niasse/velos_viz/data/*.json")
list_files

# %%
## Lecture données
data = pd.concat([pd.read_json(i, lines=True) for i in list_files])
data.head()
# Out:
#    intensity     laneId  ... vehicleType reversedLane
# 0       1785  188609530  ...     bicycle        False
# 1       1757  188609530  ...     bicycle        False
# 2       1137  188609530  ...     bicycle        False
# 3        632  188609530  ...     bicycle        False
# 4        945  188609530  ...     bicycle        False
#
# [5 rows x 8 columns]

# %%
data.info()

# %%
## Création variables  : date, latitude, longitude
# Fonction pour récuperer le ieme nombre d'une chaine de caractere
def get_number(text,i):
  num = re.findall(r'\d*\.\d*',text)
  return num[i]

data['date'] = pd.to_datetime(data['dateObserved'].str[:10], format='%Y-%m-%d')
data['longitude']=data['location'].astype('str').apply(lambda x: get_number(x,0)).astype('float')
data['latitude']=data['location'].astype('str').apply(lambda x: get_number(x,1)).astype('float')

data[['date', 'latitude', 'longitude']].head()
# Out:
#         date   latitude  longitude
# 0 2020-03-12  43.616209   3.874408
# 1 2020-03-13  43.616209   3.874408
# 2 2020-03-14  43.616209   3.874408
# 3 2020-03-15  43.616209   3.874408
# 4 2020-03-16  43.616209   3.874408

# %%
## NB Velos par jour : 
data_jour = data[['date', 'id']].groupby("date").agg({'id' : 'count'})
data_jour.plot()

# %%
px.scatter_mapbox(data, lat='latitude', lon='longitude', zoom=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a2704532-7c69-4859-ad93-704dd183b40d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a2704532-7c69-4859-ad93-704dd183b40d")) {
#                     Plotly.newPlot(
#                         'a2704532-7c69-4859-ad93-704dd183b40d',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "latitude=%{lat}<br>longitude=%{lon}", "lat": [43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 43.61620945549243, 4 ...

# %%
## Recuperer les addresses associées aux coordonnées lat, lon : 
data['geom'] = data["latitude"].map(str) + "," + data['longitude'].map(str)
locator = Nominatim(user_agent="myGeocoder", timeout=10)
rgeocode = RateLimiter(locator.reverse, min_delay_seconds=0.001)

tqdm.tqdm_pandas(tqdm_notebook)
data["address"] = data["geom"].progress_apply(rgeocode)
data.head()
# Out:
# TqdmDeprecationWarning: Please use `tqdm.pandas(...)` instead of `tqdm_pandas(tqdm, ...)`.
# /usr/local/lib/python3.7/dist-packages/tqdm/std.py:658: FutureWarning:
#
# The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
# HBox(children=(FloatProgress(value=0.0, max=2152.0), HTML(value='')))
#    intensity  ...                                            address
# 0       1785  ...  (Site Saint-Charles - Annexe Montpellier 3, Pl...
# 1       1757  ...  (Site Saint-Charles - Annexe Montpellier 3, Pl...
# 2       1137  ...  (Site Saint-Charles - Annexe Montpellier 3, Pl...
# 3        632  ...  (Site Saint-Charles - Annexe Montpellier 3, Pl...
# 4        945  ...  (Site Saint-Charles - Annexe Montpellier 3, Pl...
#
# [5 rows x 13 columns]

# %%
data['address'].astype('str').value_counts()
# Out:
# Passerelle du Moulin de l'Évêque, La Pompignane, Port Marianne, Montpellier, Hérault, Occitanie, France métropolitaine, 34064, France             366
# Avenue François Delmas, Les Aubes, Centre, Montpellier, Hérault, Occitanie, France métropolitaine, 3400, France                                   355
# Site Saint-Charles - Annexe Montpellier 3, Place Albert 1er, Boutonnet, Centre, Montpellier, Hérault, Occitanie, France métropolitaine, France    295
# Kiloutou, Avenue Georges Frêche, Pailletrice, Pérols, Montpellier, Hérault, Occitanie, France métropolitaine, 34470, France                       196
# Quick, Avenue Georges Frêche, Pailletrice, Pérols, Montpellier, Hérault, Occitanie, France métropolitaine, 34470, France                          196
# D 5, Lavérune, Montpellier, Hérault, Occitanie, France métropolitaine, 34880, France                                                              195
# Avenue de Lodève, Alco, Les Cévennes, Montpellier, Hérault, Occitanie, France métropolitaine, 34185, France                                       195
# 1, Rue Gerhardt, Centre Historique, Centre, Montpellier, Hérault, Occitanie, France métropolitaine, 34967, France                                 177
# Rue de la Vieille Poste, Millénaire, Port Marianne, Montpellier, Hérault, Occitanie, France métropolitaine, 34006, France                         177
# Name: address, dtype: int64

# %%
# Mettre des codes sur les adresses au lieu des noms 
loc = data['address'].astype('str').unique().tolist()
code_location = { x : str(y) for x,y in zip(loc, range(len(loc)))}

# %%
## NB Velos par adresse : 
data_local = data[['address', 'id']]
data_local['address'] = data_local['address'].astype('str')
data_local['address'] = data_local['address'].map(code_location)
data_local.groupby("address").agg({'id' : 'count'}).plot()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data.to_excel('/content/drive/My Drive/Data science/Projets Niasse/velos_viz/data/all_data.xlsx')
