# %%
Nous allons une combinaison de Resample et aggreate

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
#from paylab import rcParams
import seaborn as sb
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale
#from collection import Counter
import datetime as dt

# %%
don  = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQVtdpXMHB4g9h75a0jw8CsrqSuQmP5eMIB2adpKR5hkRggwMwzFy5kB-AIThodhVHNLxlZYm8fuoWj/pub?gid=2105854808&single=true&output=csv', index_col = 'Date', parse_dates = True)
don
# Out:
#            Heure / Time  Vélos depuis le 1er janvier / Grand total  \
# Date
# NaT                 NaN                                        NaN
# NaT                 NaN                                        NaN
# 2020-12-03     11:05:00                                      109.0
# 2020-12-03     14:30:00                                      441.0
# 2020-03-13     10:02:00                                     1921.0
# ...                 ...                                        ...
# 2021-03-30     19:23:00                                   108579.0
# 2021-03-31     09:16:00                                   109131.0
# 2021-03-31     09:50:00                                   109211.0
# 2021-03-31     15:04:00                                   109811.0
# 2021-03-31     16:27:00                                   109971.0
#
#             Vélos ce jour / Today's total  Unnamed: 4 Remarque
# Date
# NaT                                   NaN         NaN      NaN
# ...

# %%
import datetime as dt 
from datetime import datetime
#don['date'] = pd.to_datetime(don['jour_debut']).dt.to_period('J')
don['date'] = pd.to_datetime(Date,'%d')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-dae68fe65258> in <module>
#       2 from datetime import datetime
#       3 #don['date'] = pd.to_datetime(don['jour_debut']).dt.to_period('J')
# ----> 4 don['date'] = pd.to_datetime(Date,'%d')
#
# NameError: name 'Date' is not defined

# %%
don.head()
# Out:
#            Heure / Time  Vélos depuis le 1er janvier / Grand total  \
# Date
# NaT                 NaN                                        NaN
# NaT                 NaN                                        NaN
# 2020-12-03     11:05:00                                      109.0
# 2020-12-03     14:30:00                                      441.0
# 2020-03-13     10:02:00                                     1921.0
#
#             Vélos ce jour / Today's total  Unnamed: 4 Remarque
# Date
# NaT                                   NaN         NaN      NaN
# NaT                                   NaN         NaN      NaN
# 2020-12-03                          109.0         NaN      NaN
# 2020-12-03                          441.0         NaN      NaN
# 2020-03-13                          385.0         NaN      NaN

# %%
don = don.drop(['Unnamed: 4', 'Remarque'], axis = 1)
don
# Out:
#            Heure / Time  Vélos depuis le 1er janvier / Grand total  \
# Date
# NaT                 NaN                                        NaN
# NaT                 NaN                                        NaN
# 2020-12-03     11:05:00                                      109.0
# 2020-12-03     14:30:00                                      441.0
# 2020-03-13     10:02:00                                     1921.0
# ...                 ...                                        ...
# 2021-03-30     08:35:00                                   107125.0
# 2021-03-30     09:12:00                                   107247.0
# 2021-03-30     09:24:00                                   107266.0
# 2021-03-30     13:58:00                                   107711.0
# 2021-03-30     19:23:00                                   108579.0
#
#             Vélos ce jour / Today's total
# Date
# NaT                                   NaN
# NaT                                   NaN
# ...

# %%
don = don.dropna( axis = 0)
don
# Out:
#            Heure / Time  Vélos depuis le 1er janvier / Grand total  \
# Date
# 2020-12-03     11:05:00                                      109.0
# 2020-12-03     14:30:00                                      441.0
# 2020-03-13     10:02:00                                     1921.0
# 2020-03-13     14:15:00                                     2305.0
# 2020-03-13     18:21:00                                     2822.0
# ...                 ...                                        ...
# 2021-03-30     08:35:00                                   107125.0
# 2021-03-30     09:12:00                                   107247.0
# 2021-03-30     09:24:00                                   107266.0
# 2021-03-30     13:58:00                                   107711.0
# 2021-03-30     19:23:00                                   108579.0
#
#             Vélos ce jour / Today's total
# Date
# 2020-12-03                          109.0
# 2020-12-03                          441.0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-d04ecd7b1c2a> in <module>
# ----> 1 don['Date'] = pd.to_datetime(Date,"%d-%m-%Y").timetuple().tm_yday
#
# NameError: name 'Date' is not defined

# %%
import datetime as dt 
from datetime import datetime
date = raw_input("Enter date: ")  ## format is 02-02-2016
adate = datetime.datetime.strptime(date,"%d-%m-%Y")
day_of_year = adate.timetuple().tm_yday
day_of_year
#strftime('%j')
#donn['Date'] = pd.to_datetime(don['Date']).dt.to_period('J')
#don['Date'] = don['Date'].map(dt.datetime.toordinal)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-652f563f4466> in <module>
#       2 from datetime import datetime
# ...

# %% [markdown]
# On a maintenant 1404 individus en 3 collones

# %%
X = don[ "Vélos depuis le 1er janvier / Grand total"]
y = don["Vélos ce jour / Today's total"]
#%%
from sklearn import linear_model
#%%
from sklearn.linear_model import LinearRegression
#%%
regr = linear_model.LinearRegression()
regr.fit(X, y)
#%%
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
pred = regr.predict(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-696dab813762> in <module>
#       7 #%%
#       8 regr = linear_model.LinearRegression()
# ----> 9 regr.fit(X, y)
#      10 #%%
#      11 LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
donnés.describe() # statistique descriptive. descrire
# Out:
#        Vélos depuis le 1er janvier / Grand total  \
# count                                1493.000000
# mean                               108767.632954
# std                                 94328.889914
# min                                    49.000000
# 25%                                 28489.000000
# 50%                                 82149.000000
# 75%                                173555.000000
# max                                328401.000000
#
#        Vélos ce jour / Today's total
# count                    1493.000000
# mean                      653.008038
# std                       566.083055
# min                         0.000000
# 25%                       186.000000
# 50%                       478.000000
# 75%                      1000.000000
# max                      2605.000000

# %%
donnés.loc["2021-04-02 08:00:00  " , "Vélos ce jour / Today's total"].resample("D").agg(['mean', 'std', 'min', 'max']).dropna(axis = 0)

#donnés.loc["2021-04-02 08:00:00 " , "Vélos ce jour / Today's total"].resample("D").mean().plot(label='moyenne par jour')
#donnés.loc["2021-03 " , "Vélos ce jour / Today's total"].plot()
#plt.legend()
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2021-04-02 08:00:00  '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-684484122bae> in <module>
# ...

# %%
donnés.loc["2021-04-02 " , "Vélos ce jour / Today's total"].resample("D").agg(['mean', 'std', 'min', 'max'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2021-04-02 '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-7212573fcd8f> in <module>
# ...

# %%
df = donnés.drop(["Vélos depuis le 1er janvier / Grand total"], axis =1)
df
# Out:
#            Heure / Time [ATTENTION TOTEM EST RESTÉ À L'HEURE D'HIVER]  \
# Date
# 2020-12-03                                           11:05:00
# 2020-12-03                                           14:30:00
# 2020-03-13                                           10:02:00
# 2020-03-13                                           14:15:00
# 2020-03-13                                           18:21:00
# ...                                                       ...
# 2021-03-29                                           14:00:00
# 2021-03-29                                           15:43:00
# 2021-03-29                                           16:09:00
# 2021-03-29                                           16:42:00
# 2021-03-29                                           18:49:00
#
#             Vélos ce jour / Today's total
# Date
# 2020-12-03                          109.0
# 2020-12-03                          441.0
# 2020-03-13                          385.0
# ...
